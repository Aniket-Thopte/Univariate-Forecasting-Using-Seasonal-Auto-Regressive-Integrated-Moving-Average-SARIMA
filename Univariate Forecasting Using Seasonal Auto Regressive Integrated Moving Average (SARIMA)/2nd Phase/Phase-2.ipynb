# %% [markdown]
# ## Phase 2 | Aniket Amar Thopte

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('exam1.csv')

# %%
df.head(10)
# Out:
#    ID   Var
# 0   1  58.4
# 1   2  58.4
# 2   3  66.5
# 3   4  73.3
# 4   5  76.2
# 5   6  78.4
# 6   7  80.0
# 7   8  79.6
# 8   9  80.2
# 9  10  75.6

# %%
df.tail(5)
# Out:
#     ID   Var
# 59  60  63.7
# 60  61  60.4
# 61  62  57.7
# 62  63  65.6
# 63  64  68.1

# %%
df[['Var']].plot(figsize=(12,8))

# %%
model=sm.tsa.statespace.SARIMAX(df['Var'],order=(1, 0, 0),seasonal_order=(0,1,1,12))
results=model.fit()

# %%
df['forecast']=results.predict(start=15,end=63,dynamic=True)
df[['Var','forecast']].plot(figsize=(12,8))

# %%
predicted=df['forecast'][15:]

# %%
true=df['Var'][15:]

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(true,predicted)
# Out:
# 2.487560862675623

# %%
future_dates=[df.index[-1]+i for i in range(0,5)]

# %%
future_datest_df=pd.DataFrame(index=future_dates[1:],columns=df.columns)

# %%
future_datest_df
# Out:
#      ID  Var forecast
# 64  NaN  NaN      NaN
# 65  NaN  NaN      NaN
# 66  NaN  NaN      NaN
# 67  NaN  NaN      NaN

# %%
future_df=pd.concat([df,future_datest_df])

# %%
future_df['forecast'] = results.predict(start = 62, end = 67, dynamic= True)  
future_df[['Var', 'forecast']].plot(figsize=(12, 8))

# %%
future_df['forecast'][63:]
# Out:
# 63    69.874277
# 64    75.095068
# 65    79.302667
# 66    81.157423
# 67    81.232281
# Name: forecast, dtype: float64
